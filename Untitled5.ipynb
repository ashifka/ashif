# %% [markdown]
# <a href="https://colab.research.google.com/github/ashifka/ashif/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel('/content/drive/MyDrive/iris.xls')
display(df)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
print(df.mean(numeric_only = True))
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
sns.countplot(x ='PW',data = df,hue ='Classification',palette = 'viridis')
# Out:
# <Axes: xlabel='PW', ylabel='count'>

# %%
sns.distplot(df.SL,bins = 20,color = 'r')
# Out:
# <ipython-input-23-3daf2ed3b00e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.SL,bins = 20,color = 'r')
# <Axes: xlabel='SL', ylabel='Density'>

# %%
sns.kdeplot(df.SW,color = 'b')
# Out:
# <Axes: xlabel='SW', ylabel='Density'>

# %%
sns.boxplot(x = 'PW',data =df,color = 'y')
# Out:
# <Axes: xlabel='PW'>

# %%
sns.violinplot(x = df.PL,color = 'g')
# Out:
# <Axes: xlabel='PL'>

# %%
sns.lineplot(x = 'SL',y ='SW',hue = 'Classification',data = df)
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %%
sns.scatterplot(x = 'PL', y = 'PW',hue = 'Classification',data = df)
# Out:
# <Axes: xlabel='PL', ylabel='PW'>

# %%
sns.jointplot(x = 'SL', y = 'PL',hue ='Classification',data = df)

# %%
sns.barplot(x = 'PW', y = 'SW',hue ='Classification',data = df)
# Out:
# <Axes: xlabel='PW', ylabel='SW'>

# %%
sns.heatmap(data = df.corr(),annot = True)
# Out:
# <ipython-input-50-5cd048fbf621>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data = df.corr(),annot = True)
# <Axes: >
